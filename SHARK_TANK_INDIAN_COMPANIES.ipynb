# %% [markdown]
# <a href="https://colab.research.google.com/github/rohithreddy999/Machine_learning-AI-predictions/blob/main/SHARK_TANK_INDIAN_COMPANIES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/ShartankIndiaAllPitches.csv")

# %%
df.head()
# Out:
#    Episode Number                Brand  Investment Amount (In Lakhs INR)  \
# 0               1  BluePine Industries                                75
# 1               1        Booz scooters                                40
# 2               1  Heart up my Sleeves                                25
# 3               2           Tagz Foods                                70
# 4               2       Head and Heart                                 0
#
#    Debt (In lakhs INR) Equity Anupam Ashneer Namita Aman Peyush Vineeta  \
# 0                    0    18%      N       Y      N    Y      N       Y
# 1                    0    50%      N       Y      N    N      N       Y
# 2                    0    30%      Y       N      N    N      N       Y
# 3                    0     3%      N       Y      N    N      N       N
# 4                    0     0%      N       N      N    N      N       N
#
#   Ghazal  Season
# 0      N       1
# 1      N       1
# 2      N       1
# 3      N       1
# ...

# %%
df.isnull().sum()
# Out:
# Episode Number                      0
# Brand                               0
# Investment Amount (In Lakhs INR)    0
# Debt (In lakhs INR)                 0
# Equity                              0
# Anupam                              0
# Ashneer                             0
# Namita                              0
# Aman                                0
# Peyush                              0
# Vineeta                             0
# Ghazal                              0
# Season                              0
# dtype: int64

# %%
df.Equity.unique()
# Out:
# array(['18%', '50%', '30%', '3%', '0%', '6%', '15%', '25%', '8%', '2%',
#        '20%', '4%', '33%', '7%', '10%', '5%', '24%', '40%', '12%', '1%',
#        '75%', '35%', '21%'], dtype=object)

# %%
df.Brand.unique()
# Out:
# array(['BluePine Industries', 'Booz scooters', 'Heart up my Sleeves',
#        'Tagz Foods', 'Head and Heart', 'Agro tourism', 'Qzense Labs',
#        'Peeschute', 'NOCD', 'Cosiq', 'JhaJi Achaar', 'Bummer',
#        'Revamp Moto', 'Hungry Heads', 'Shrawani Engineers', 'Skippi Pops',
#        'Menstrupedia', 'Hecolll', 'Raising Superstars', 'Torch-it',
#        'La Kheer Deli', 'Beyond Snack', 'Vivalyf Innovations- Easy Life',
#        'Motion Breeze', 'Altor', 'Ariro', 'Kabira Handmade', 'Nuutjob',
#        'Meatyour', 'EventBeep', "Gopal's 56", 'ARRCOAT Surface Textures',
#        'Farda', 'Auli Lifestyle', 'SweeDesi', 'LOKA', 'Annie',
#        'Caragreen', 'The Yarn Bazaar', 'The Renal Project',
#        'Morikko Pure Foods', 'Good Good Piggy Bank', 'Hammer Lifestyle',
#        'PNT', 'Cocofit', 'Bamboo India', 'Flying Furr', 'Beyond Water',
#        "Let's Try", 'Find Your Kicks India', 'Aas Vidyalaya', 'Outbox',
# ...

# %%
df.Anupam.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %% [markdown]
# PERCENTAGE OF YES AND NO OF ANUPAM INVESTMENTS FOR COMAPNY'S

# %%
plt.pie(df.Anupam.value_counts(),[0.1,0],labels=['N','Y'],autopct = "%1.1f%%",colors = ['red','yellow'],shadow=True)
plt.title('Anupam')
plt.show()

# %% [markdown]
# PERCENTAGE OF YES AND NO OF Ashneer INVESTMENTS FOR COMAPNY'S

# %%
plt.pie(df.Ashneer.value_counts(),[0.1,0],labels=['N','Y'],autopct = "%1.1f%%",colors = ['red','yellow'],shadow=True)
plt.title('Ashneer')
plt.show()

# %% [markdown]
# PERCENTAGE OF YES AND NO OF Namita INVESTMENTS FOR COMAPNY'S

# %%
plt.pie(df.Namita.value_counts(),[0.1,0],labels=['N','Y'],autopct = "%1.1f%%",colors = ['red','yellow'],shadow=True)
plt.title('Namita')
plt.show()

# %% [markdown]
# PERCENTAGE OF YES AND NO OF Aman INVESTMENTS FOR COMAPNY'S

# %%
plt.pie(df.Aman.value_counts(),[0.1,0],labels=['N','Y'],autopct = "%1.1f%%",colors = ['red','yellow'],shadow=True)
plt.title('Aman')
plt.show()

# %% [markdown]
# PERCENTAGE OF YES AND NO OF Ashneer INVESTMENTS FOR COMAPNY'S

# %%
plt.pie(df.Ashneer.value_counts(),[0.1,0],labels=['N','Y'],autopct = "%1.1f%%",colors = ['red','yellow'],shadow=True)
plt.title('Ashneer')
plt.show()

# %% [markdown]
# PERCENTAGE OF YES AND NO OF Vineeta INVESTMENTS FOR COMAPNY'S

# %%
plt.pie(df.Vineeta.value_counts(),[0.1,0],labels=['N','Y'],autopct = "%1.1f%%",colors = ['red','yellow'],shadow=True)
plt.title('Vineeta')
plt.show()

# %% [markdown]
# PERCENTAGE OF YES AND NO OF Ghazal INVESTMENTS FOR COMAPNY'S

# %%
plt.pie(df.Ghazal.value_counts(),[0.1,0],labels=['N','Y'],autopct = "%1.1f%%",colors = ['red','yellow'],shadow=True)
plt.title('Ghazal')
plt.show()

# %%
sns.swarmplot(x= df.Anupam,y =df.Brand)
plt.figure(figsize=(120,120))

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#    Episode Number                Brand  Investment Amount (In Lakhs INR)  \
# 0               1  BluePine Industries                                75
# 1               1        Booz scooters                                40
# 2               1  Heart up my Sleeves                                25
# 3               2           Tagz Foods                                70
# 4               2       Head and Heart                                 0
#
#    Debt (In lakhs INR) Equity Anupam Ashneer Namita Aman Peyush Vineeta  \
# 0                    0    18%      N       Y      N    Y      N       Y
# 1                    0    50%      N       Y      N    N      N       Y
# 2                    0    30%      Y       N      N    N      N       Y
# 3                    0     3%      N       Y      N    N      N       N
# 4                    0     0%      N       N      N    N      N       N
#
#   Ghazal  Season
# 0      N       1
# 1      N       1
# 2      N       1
# 3      N       1
# ...

# %% [markdown]
# THE COMPANYS ANUPAM HAD INVESTED

# %%
sns.clustermap(pd.crosstab(df['Anupam'],df['Brand']))
plt.show()

# %% [markdown]
# THE COMPANYS Ashneer HAD INVESTED

# %%
sns.clustermap(pd.crosstab(df['Ashneer'],df['Brand']))
plt.show()

# %% [markdown]
# THE COMPANYS Namita HAD INVESTED

# %%
sns.clustermap(pd.crosstab(df['Namita'],df['Brand']))
plt.show()

# %% [markdown]
# THE COMPANYS Aman HAD INVESTED

# %%
sns.clustermap(pd.crosstab(df['Aman'],df['Brand']))
plt.show()

# %% [markdown]
# THE COMPANYS Peyush HAD INVESTED

# %%
sns.clustermap(pd.crosstab(df['Peyush'],df['Brand']))
plt.show()

# %% [markdown]
# THE COMPANYS Vineeta HAD INVESTED

# %%
sns.clustermap(pd.crosstab(df['Vineeta'],df['Brand']))
plt.show()

# %% [markdown]
# THE COMPANYS Ghazal HAD INVESTED

# %%
sns.clustermap(pd.crosstab(df['Ghazal'],df['Brand']))
plt.show()

# %%
df.head(2)
# Out:
#    Episode Number                Brand  Investment Amount (In Lakhs INR)  \
# 0               1  BluePine Industries                                75
# 1               1        Booz scooters                                40
#
#    Debt (In lakhs INR) Equity Anupam Ashneer Namita Aman Peyush Vineeta  \
# 0                    0    18%      N       Y      N    Y      N       Y
# 1                    0    50%      N       Y      N    N      N       Y
#
#   Ghazal  Season
# 0      N       1
# 1      N       1

# %% [markdown]
# AMOUNT INVESTMENT(IN LAKHS) AND DEBT_AMOUNT BY AMAN IN COMPANY'S

# %%
Invested_amount = df[df['Anupam']=='Y']['Investment Amount (In Lakhs INR)'].sum()
Invested_amount
# Out:
# 816

# %%
Debt_amount = df[df['Anupam']=='Y']['Debt (In lakhs INR)'].sum()
Debt_amount
# Out:
# 30

# %% [markdown]
# AMOUNT INVESTMENT(IN LAKHS)AND DEBT_AMOUNT BY AMAN IN COMPANY'S

# %%
Invested_amount = df[df['Aman']=='Y']['Investment Amount (In Lakhs INR)'].sum()
Invested_amount
# Out:
# 1060

# %%
Debt_amount = df[df['Aman']=='Y']['Debt (In lakhs INR)'].sum()
Debt_amount
# Out:
# 50

# %% [markdown]
# AMOUNT INVESTMENT(IN LAKHS) AND DEBT_AMOUNT BY Namita IN COMPANY'S

# %%
Invested_amount = df[df['Namita']=='Y']['Investment Amount (In Lakhs INR)'].sum()
Invested_amount
# Out:
# 870

# %%
Debt_amount = df[df['Namita']=='Y']['Debt (In lakhs INR)'].sum()
Debt_amount
# Out:
# 0

# %% [markdown]
# AMOUNT INVESTMENT(IN LAKHS)AND DEBT_AMOUNT BY Peyush IN COMPANY'S

# %%
Invested_amount = df[df['Peyush']=='Y']['Investment Amount (In Lakhs INR)'].sum()
Invested_amount
# Out:
# 886

# %%
Debt_amount = df[df['Peyush']=='Y']['Debt (In lakhs INR)'].sum()
Debt_amount
# Out:
# 92

# %% [markdown]
# AMOUNT INVESTMENT(IN LAKHS)AND DEBT_AMOUNT BY Vineeta IN COMPANY'S

# %%
Invested_amount = df[df['Vineeta']=='Y']['Investment Amount (In Lakhs INR)'].sum()
Invested_amount
# Out:
# 570

# %%
Debt_amount = df[df['Vineeta']=='Y']['Debt (In lakhs INR)'].sum()
Debt_amount
# Out:
# 30

# %% [markdown]
# AMOUNT INVESTMENT(IN LAKHS) AND DEBT_AMOUNT BY Ghazal IN COMPANY'S

# %%
Invested_amount = df[df['Ghazal']=='Y']['Investment Amount (In Lakhs INR)'].sum()
Invested_amount
# Out:
# 245

# %%
Debt_amount = df[df['Ghazal']=='Y']['Debt (In lakhs INR)'].sum()
Debt_amount
# Out:
# 0

# %%
sns.scatterplot(x='Equity', y='Investment Amount (In Lakhs INR)', data=df)
plt.show()

# %%
plt.scatter(df['Debt (In lakhs INR)'], df['Episode Number'])
plt.xlabel('Debt (In lakhs INR)')
plt.ylabel('Episode Number')
plt.title('Debt vs Episode Number')
plt.show()

# %%
sns.scatterplot(data=df ,x='Equity', y='Debt (In lakhs INR)')
plt.show()

# %%
sns.scatterplot(data=df,x='Equity', y='Investment Amount (In Lakhs INR)')
plt.show()

# %%
sns.violinplot(data=df,x='Equity', y='Investment Amount (In Lakhs INR)')
# Out:
# <Axes: xlabel='Equity', ylabel='Investment Amount (In Lakhs INR)'>

# %%
sns.violinplot(data=df,x='Equity', y='Debt (In lakhs INR)')
# Out:
# <Axes: xlabel='Equity', ylabel='Debt (In lakhs INR)'>

# %%
sns.lineplot(x=df['Episode Number'],y=df["Equity"])
# Out:
# <Axes: xlabel='Episode Number', ylabel='Equity'>

# %%
sns.lineplot(x=df['Season'],y=df["Equity"])
# Out:
# <Axes: xlabel='Season', ylabel='Equity'>

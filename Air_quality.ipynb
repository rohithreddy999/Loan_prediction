# %% [markdown]
# <a href="https://colab.research.google.com/github/rohithreddy999/Machine_learning-AI-predictions/blob/main/Air_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("AQI Data Set.csv")

# %%
df.head()
# Out:
#    Id Mounths  PM10 in æg/m3  SO2 in æg/m3  NOx  in æg/m3   PM2.5  in æg/m3  \
# 0   1  Jan-17          174.0          26.4           35.0                79
# 1   2  Feb-17          143.0          35.1           40.3                75
# 2   3  Mar-17          142.0          32.1           30.9                59
# 3   4  Apr-17          117.0          50.9           36.3                75
# 4   5  May-17            NaN          41.6           25.2                53
#
#    Ammonia - NH3  in æg/m3  O3   in æg/m3  CO  in mg/m3   Benzene  in æg/m3  \
# 0                     25.0          107.6           0.9                 0.7
# 1                     31.0          103.0           0.9                 0.9
# 2                     26.0           80.7           0.8                 0.5
# 3                     36.0           79.5           0.9                 0.7
# 4                     28.0           70.0           0.5                 0.5
#
#      AQI
# 0  149.0
# 1  129.0
# 2  128.0
# 3  111.0
# 4    NaN

# %%
df.Mounths.unique()
# Out:
# array(['Jan-17', 'Feb-17', 'Mar-17', 'Apr-17', 'May-17', 'Jun-17',
#        'Jul-17', 'Aug-17', 'Sep-17', 'Oct-17', 'Nov-17', 'Dec-17',
#        'Jan-18', 'Feb-18', 'Mar-18', 'Apr-18', 'May-18', 'Jun-18',
#        'Jul-18', 'Aug-18', 'Sep-18', 'Oct-18', 'Nov-18', 'Dec-18',
#        'Jan-19', 'Feb-19', 'Mar-19', 'Apr-19', 'May-19', 'Jun-19',
#        'Jul-19', 'Aug-19', 'Sep-19', 'Oct-19', 'Nov-19', 'Dec-19',
#        'Jan-20', 'Feb-20', 'Mar-20', 'Apr-20', 'May-20', 'Jun-20',
#        'Jul-20', 'Aug-20', 'Sep-20', 'Oct-20', 'Nov-20', 'Dec-20',
#        'Jan-21', 'Feb-21', 'Mar-21', 'Apr-21', 'May-21', 'Jun-21',
#        'Jul-21', 'Aug-21', 'Sep-21', 'Oct-21', 'Nov-21', 'Dec-21',
#        'Jan-22', 'Feb-22', 'Mar-22', 'Apr-22', 'May-22', 'Jun-22',
#        'Jul-22', 'Aug-22', 'Sep-22', 'Oct-22', 'Nov-22', 'Dec-22'],
#       dtype=object)

# %%
df.drop(columns=["Id"	,"Mounths"],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    PM10 in æg/m3  SO2 in æg/m3  NOx  in æg/m3   PM2.5  in æg/m3  \
# 0          174.0          26.4           35.0                79
# 1          143.0          35.1           40.3                75
# 2          142.0          32.1           30.9                59
# 3          117.0          50.9           36.3                75
# 4            NaN          41.6           25.2                53
#
#    Ammonia - NH3  in æg/m3  O3   in æg/m3  CO  in mg/m3   Benzene  in æg/m3  \
# 0                     25.0          107.6           0.9                 0.7
# 1                     31.0          103.0           0.9                 0.9
# 2                     26.0           80.7           0.8                 0.5
# 3                     36.0           79.5           0.9                 0.7
# 4                     28.0           70.0           0.5                 0.5
#
#      AQI
# 0  149.0
# 1  129.0
# 2  128.0
# 3  111.0
# 4    NaN

# %%
df.isnull().sum()
# Out:
# PM10 in æg/m3              6
# SO2 in æg/m3               1
# NOx  in æg/m3              2
#  PM2.5  in æg/m3           0
# Ammonia - NH3  in æg/m3    0
# O3   in æg/m3              0
# CO  in mg/m3               0
#  Benzene  in æg/m3         0
# AQI                        5
# dtype: int64

# %%
sns.distplot(df["PM10 in æg/m3"])
# Out:
# <ipython-input-8-abf1a3e3a87c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["PM10 in æg/m3"])
# <Axes: xlabel='PM10 in æg/m3', ylabel='Density'>

# %%
sns.distplot(df["SO2 in æg/m3"])
# Out:
# <ipython-input-9-47f596386511>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["SO2 in æg/m3"])
# <Axes: xlabel='SO2 in æg/m3', ylabel='Density'>

# %%
sns.distplot(df["NOx  in æg/m3"])
# Out:
# <ipython-input-10-0051830ef3ff>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["NOx  in æg/m3"])
# <Axes: xlabel='NOx  in æg/m3', ylabel='Density'>

# %%
sns.distplot(df.AQI)
# Out:
# <ipython-input-11-11c6e76c7fba>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.AQI)
# <Axes: xlabel='AQI', ylabel='Density'>

# %% [markdown]
# The above graphs are Right skewed graph

# %%
df["PM10 in æg/m3"].fillna(df["PM10 in æg/m3"].mean(),inplace=True)
df["SO2 in æg/m3"].fillna(df["SO2 in æg/m3"].mean(),inplace=True)
df["NOx  in æg/m3"].fillna(df["NOx  in æg/m3"].mean(),inplace=True)
df["AQI"].fillna(df["AQI"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PM10 in æg/m3              0
# SO2 in æg/m3               0
# NOx  in æg/m3              0
#  PM2.5  in æg/m3           0
# Ammonia - NH3  in æg/m3    0
# O3   in æg/m3              0
# CO  in mg/m3               0
#  Benzene  in æg/m3         0
# AQI                        0
# dtype: int64

# %%
df.head()
# Out:
#    PM10 in æg/m3  SO2 in æg/m3  NOx  in æg/m3   PM2.5  in æg/m3  \
# 0     174.000000          26.4           35.0                79
# 1     143.000000          35.1           40.3                75
# 2     142.000000          32.1           30.9                59
# 3     117.000000          50.9           36.3                75
# 4     109.393939          41.6           25.2                53
#
#    Ammonia - NH3  in æg/m3  O3   in æg/m3  CO  in mg/m3   Benzene  in æg/m3  \
# 0                     25.0          107.6           0.9                 0.7
# 1                     31.0          103.0           0.9                 0.9
# 2                     26.0           80.7           0.8                 0.5
# 3                     36.0           79.5           0.9                 0.7
# 4                     28.0           70.0           0.5                 0.5
#
#           AQI
# 0  149.000000
# 1  129.000000
# 2  128.000000
# 3  111.000000
# 4  105.571642

# %% [markdown]
# OUTLIER DETECTION

# %%
sns.boxplot(df.AQI)
# Out:
# <Axes: >

# %%
q1=df.AQI.quantile(0.25)
q3=df.AQI.quantile(0.75)

# %%
IQR=q3-q1
IQR
# Out:
# 27.0

# %%
upper_limit = q3+1.5*IQR
lower_limit = q1-1.5*IQR

# %%
df.median()
# Out:
# PM10 in æg/m3              105.50
# SO2 in æg/m3                14.10
# NOx  in æg/m3               29.75
#  PM2.5  in æg/m3            47.00
# Ammonia - NH3  in æg/m3     23.00
# O3   in æg/m3               20.75
# CO  in mg/m3                 0.50
#  Benzene  in æg/m3           0.20
# AQI                        104.50
# dtype: float64

# %%
df['AQI'] =np.where(df['AQI']>upper_limit,104,df['AQI'])

# %%
sns.boxplot(df.AQI)
# Out:
# <Axes: >

# %%
x=df.drop(columns=["AQI"],axis=1)
x.head()
# Out:
#    PM10 in æg/m3  SO2 in æg/m3  NOx  in æg/m3   PM2.5  in æg/m3  \
# 0     174.000000          26.4           35.0                79
# 1     143.000000          35.1           40.3                75
# 2     142.000000          32.1           30.9                59
# 3     117.000000          50.9           36.3                75
# 4     109.393939          41.6           25.2                53
#
#    Ammonia - NH3  in æg/m3  O3   in æg/m3  CO  in mg/m3   Benzene  in æg/m3
# 0                     25.0          107.6           0.9                 0.7
# 1                     31.0          103.0           0.9                 0.9
# 2                     26.0           80.7           0.8                 0.5
# 3                     36.0           79.5           0.9                 0.7
# 4                     28.0           70.0           0.5                 0.5

# %%
y=df.AQI
y.head()
# Out:
# 0    149.000000
# 1    129.000000
# 2    128.000000
# 3    111.000000
# 4    105.571642
# Name: AQI, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((50, 8), (22, 8), (50,), (22,))

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred=lm.predict(xtest)

# %%
#evaluation metrics
#MEAN SQUARD ERROR
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest, y_pred)
print('Mean Squared Error:', mse)
#ROOT MEAN SQUARED ERROR
import numpy as np
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest, y_pred)
rmse = np.sqrt(mse)
print('Root Mean Squared Error:', rmse)
#MEAN ABSOLUTE ERROR
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(ytest, y_pred)
print('Mean Absolute Error:', mae)
# Out:
# Mean Squared Error: 394.89184809198593
# Root Mean Squared Error: 19.87188587155195
# Mean Absolute Error: 15.33201108193001

# %%
# ANN REGRESSION MODEL
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
reg_model=Sequential()
#Adding the input layer
reg_model.add(Dense(7,activation="relu"))
#Adding four hidden layers
reg_model.add(Dense(128,activation="relu"))
reg_model.add(Dense(64,activation="relu"))
reg_model.add(Dense(32,activation="relu"))
reg_model.add(Dense(16,activation="relu"))
#Adding the output layer
reg_model.add(Dense(1,activation="linear"))

# %%
#compiling the model
reg_model.compile(optimizer="adam",loss="mse",metrics=['mse','mae'])
#fitting the ann regression model to the training data
reg_model.fit(xtrain,ytrain,epochs=10,batch_size=2,validation_data=(xtest,ytest))
# Out:
# Epoch 1/40
# 25/25 [==============================] - 8s 13ms/step - loss: 4429.2598 - mse: 4429.2598 - mae: 57.6571 - val_loss: 396.4785 - val_mse: 396.4785 - val_mae: 15.2955
# Epoch 2/40
# 25/25 [==============================] - 0s 5ms/step - loss: 431.4279 - mse: 431.4279 - mae: 15.8900 - val_loss: 415.0138 - val_mse: 415.0138 - val_mae: 13.8633
# Epoch 3/40
# 25/25 [==============================] - 0s 5ms/step - loss: 336.6032 - mse: 336.6032 - mae: 13.0391 - val_loss: 496.8592 - val_mse: 496.8592 - val_mae: 16.1552
# Epoch 4/40
# 25/25 [==============================] - 0s 9ms/step - loss: 320.9537 - mse: 320.9537 - mae: 13.8217 - val_loss: 411.7047 - val_mse: 411.7047 - val_mae: 14.9458
# Epoch 5/40
# 25/25 [==============================] - 0s 8ms/step - loss: 297.6043 - mse: 297.6043 - mae: 11.9872 - val_loss: 361.8369 - val_mse: 361.8369 - val_mae: 13.3168
# Epoch 6/40
# 25/25 [==============================] - 0s 8ms/step - loss: 310.1233 - mse: 310.1233 - mae: 12.4290 - val_loss: 344.7820 - val_mse: 344.7820 - val_mae: 13.1835
# Epoch 7/40
# 25/25 [==============================] - 0s 7ms/step - loss: 273.8286 - mse: 273.8286 - mae: 11.2371 - val_loss: 409.5993 - val_mse: 409.5993 - val_mae: 14.3610
# Epoch 8/40
# 25/25 [==============================] - 0s 9ms/step - loss: 294.5108 - mse: 294.5108 - mae: 11.6521 - val_loss: 353.6976 - val_mse: 353.6976 - val_mae: 13.4331
# Epoch 9/40
# 25/25 [==============================] - 0s 8ms/step - loss: 278.8929 - mse: 278.8929 - mae: 11.9136 - val_loss: 401.8824 - val_mse: 401.8824 - val_mae: 14.7412
# Epoch 10/40
# 25/25 [==============================] - 0s 7ms/step - loss: 269.2047 - mse: 269.2047 - mae: 11.4820 - val_loss: 354.8087 - val_mse: 354.8087 - val_mae: 13.5954
# Epoch 11/40
# 25/25 [==============================] - 0s 8ms/step - loss: 258.7670 - mse: 258.7670 - mae: 10.7993 - val_loss: 349.8259 - val_mse: 349.8259 - val_mae: 13.6070
# Epoch 12/40
# 25/25 [==============================] - 0s 9ms/step - loss: 344.0097 - mse: 344.0097 - mae: 13.7479 - val_loss: 372.0172 - val_mse: 372.0172 - val_mae: 14.2244
# Epoch 13/40
# 25/25 [==============================] - 0s 9ms/step - loss: 252.0942 - mse: 252.0942 - mae: 11.5137 - val_loss: 344.9387 - val_mse: 344.9387 - val_mae: 13.6087
# Epoch 14/40
# 25/25 [==============================] - 0s 6ms/step - loss: 249.1532 - mse: 249.1532 - mae: 11.2901 - val_loss: 391.2534 - val_mse: 391.2534 - val_mae: 14.7789
# Epoch 15/40
# 25/25 [==============================] - 0s 7ms/step - loss: 280.6112 - mse: 280.6112 - mae: 12.7454 - val_loss: 446.3267 - val_mse: 446.3267 - val_mae: 16.0590
# Epoch 16/40
# 25/25 [==============================] - 0s 5ms/step - loss: 282.9946 - mse: 282.9946 - mae: 12.4938 - val_loss: 353.3767 - val_mse: 353.3767 - val_mae: 13.9894
# Epoch 17/40
# 25/25 [==============================] - 0s 7ms/step - loss: 308.0187 - mse: 308.0187 - mae: 13.2666 - val_loss: 361.8000 - val_mse: 361.8000 - val_mae: 13.9628
# Epoch 18/40
# 25/25 [==============================] - 0s 7ms/step - loss: 273.3292 - mse: 273.3292 - mae: 11.7238 - val_loss: 365.5449 - val_mse: 365.5449 - val_mae: 14.0424
# Epoch 19/40
# 25/25 [==============================] - 0s 5ms/step - loss: 244.2711 - mse: 244.2711 - mae: 11.2981 - val_loss: 348.4868 - val_mse: 348.4868 - val_mae: 13.7802
# Epoch 20/40
# 25/25 [==============================] - 0s 5ms/step - loss: 237.8643 - mse: 237.8643 - mae: 11.3539 - val_loss: 367.7726 - val_mse: 367.7726 - val_mae: 14.1251
# Epoch 21/40
# 25/25 [==============================] - 0s 5ms/step - loss: 279.2839 - mse: 279.2839 - mae: 12.9496 - val_loss: 352.0392 - val_mse: 352.0392 - val_mae: 14.2100
# Epoch 22/40
# 25/25 [==============================] - 0s 5ms/step - loss: 283.2464 - mse: 283.2464 - mae: 12.5842 - val_loss: 336.8363 - val_mse: 336.8363 - val_mae: 13.4994
# Epoch 23/40
# 25/25 [==============================] - 0s 6ms/step - loss: 265.6623 - mse: 265.6623 - mae: 12.3921 - val_loss: 327.0811 - val_mse: 327.0811 - val_mae: 13.2116
# Epoch 24/40
# 25/25 [==============================] - 0s 5ms/step - loss: 225.3522 - mse: 225.3522 - mae: 11.2655 - val_loss: 332.3423 - val_mse: 332.3423 - val_mae: 13.6286
# Epoch 25/40
# 25/25 [==============================] - 0s 5ms/step - loss: 219.2392 - mse: 219.2392 - mae: 11.5715 - val_loss: 477.4865 - val_mse: 477.4865 - val_mae: 16.9058
# Epoch 26/40
# 25/25 [==============================] - 0s 6ms/step - loss: 293.6802 - mse: 293.6802 - mae: 13.1848 - val_loss: 318.6268 - val_mse: 318.6268 - val_mae: 13.1605
# Epoch 27/40
# 25/25 [==============================] - 0s 5ms/step - loss: 226.8172 - mse: 226.8172 - mae: 11.2754 - val_loss: 327.9207 - val_mse: 327.9207 - val_mae: 13.4391
# Epoch 28/40
# 25/25 [==============================] - 0s 5ms/step - loss: 314.0161 - mse: 314.0161 - mae: 13.2484 - val_loss: 443.1378 - val_mse: 443.1378 - val_mae: 16.8016
# Epoch 29/40
# 25/25 [==============================] - 0s 5ms/step - loss: 283.9511 - mse: 283.9511 - mae: 13.2590 - val_loss: 357.0327 - val_mse: 357.0327 - val_mae: 14.1457
# Epoch 30/40
# 25/25 [==============================] - 0s 5ms/step - loss: 233.6940 - mse: 233.6940 - mae: 11.9272 - val_loss: 384.5314 - val_mse: 384.5314 - val_mae: 14.4207
# Epoch 31/40
# 25/25 [==============================] - 0s 5ms/step - loss: 224.5683 - mse: 224.5683 - mae: 11.2840 - val_loss: 345.3442 - val_mse: 345.3442 - val_mae: 13.9658
# Epoch 32/40
# 25/25 [==============================] - 0s 5ms/step - loss: 227.3595 - mse: 227.3595 - mae: 11.4768 - val_loss: 358.3398 - val_mse: 358.3398 - val_mae: 14.1704
# Epoch 33/40
# 25/25 [==============================] - 0s 5ms/step - loss: 316.5233 - mse: 316.5233 - mae: 13.5596 - val_loss: 385.9409 - val_mse: 385.9409 - val_mae: 15.4519
# Epoch 34/40
# 25/25 [==============================] - 0s 5ms/step - loss: 271.4731 - mse: 271.4731 - mae: 12.7802 - val_loss: 374.8718 - val_mse: 374.8718 - val_mae: 14.9585
# Epoch 35/40
# 25/25 [==============================] - 0s 5ms/step - loss: 223.3819 - mse: 223.3819 - mae: 11.5033 - val_loss: 388.0345 - val_mse: 388.0345 - val_mae: 14.4595
# Epoch 36/40
# 25/25 [==============================] - 0s 7ms/step - loss: 249.5670 - mse: 249.5670 - mae: 12.1556 - val_loss: 364.3342 - val_mse: 364.3342 - val_mae: 14.3888
# Epoch 37/40
# 25/25 [==============================] - 0s 5ms/step - loss: 212.5242 - mse: 212.5242 - mae: 12.0895 - val_loss: 418.2044 - val_mse: 418.2044 - val_mae: 16.5400
# Epoch 38/40
# 25/25 [==============================] - 0s 5ms/step - loss: 225.4996 - mse: 225.4996 - mae: 11.1431 - val_loss: 353.2537 - val_mse: 353.2537 - val_mae: 14.0002
# Epoch 39/40
# 25/25 [==============================] - 0s 5ms/step - loss: 221.0700 - mse: 221.0700 - mae: 11.4522 - val_loss: 425.3986 - val_mse: 425.3986 - val_mae: 16.5774
# Epoch 40/40
# 25/25 [==============================] - 0s 5ms/step - loss: 243.1871 - mse: 243.1871 - mae: 12.3266 - val_loss: 376.9007 - val_mse: 376.9007 - val_mae: 15.8380

# %%
#evaluation
y_pred_1=reg_model.predict(xtest)
# Out:
# 1/1 [==============================] - 0s 124ms/step

# %% [markdown]
# TESTING

# %%
reg_model.predict([[174.000000,26.4,35.0,79,25.0,107.6,0.9,0.7]])
# Out:
# 1/1 [==============================] - 0s 96ms/step
# array([[129.35777]], dtype=float32)

# %%
# Evaluate the model on test data using MSE
from tensorflow import keras
#MEAN SQUARD ERROR
from sklearn.metrics import mean_squared_error
mse_1 = mean_squared_error(ytest, y_pred)
print('Mean Squared Error:', mse_1)
#ROOT MEAN SQUARED ERROR
import numpy as np
from sklearn.metrics import mean_squared_error
mse_1 = mean_squared_error(ytest, y_pred)
rmse_1 = np.sqrt(mse_1)
print('Root Mean Squared Error:', rmse_1)
#MEAN ABSOLUTE ERROR
from sklearn.metrics import mean_absolute_error
mae_1 = mean_absolute_error(ytest, y_pred)
print('Mean Absolute Error:', mae_1)
# Out:
# Mean Squared Error: 394.89184809198593
# Root Mean Squared Error: 19.87188587155195
# Mean Absolute Error: 15.33201108193001

# %%
sns.pairplot(df)

# %%
import matplotlib.pyplot as plt
corr_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
sns.barplot(data=df,x=df['AQI'],y=df['PM10 in æg/m3'])
plt.show()

# %%
#Random forest regressor
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
y_pred_2=rf.predict(xtest)
#MEAN SQUARD ERROR
from sklearn.metrics import mean_squared_error
mse_2 = mean_squared_error(ytest, y_pred_2)
print('Mean Squared Error:', mse_2)
#ROOT MEAN SQUARED ERROR
import numpy as np
from sklearn.metrics import mean_squared_error
mse_2= mean_squared_error(ytest, y_pred_2)
rmse_2 = np.sqrt(mse_2)
print('Root Mean Squared Error:', rmse_2)
#MEAN ABSOLUTE ERROR
from sklearn.metrics import mean_absolute_error
mae_2 = mean_absolute_error(ytest, y_pred_2)
print('Mean Absolute Error:', mae_2)
# Out:
# Mean Squared Error: 274.252989765862
# Root Mean Squared Error: 16.560585429442465
# Mean Absolute Error: 11.269889416553589

# %%
#DECISION TREE REGRESSOR
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(xtrain, ytrain)
y_pred_3 = dt.predict(xtest)

# %%
#MEAN SQUARD ERROR
from sklearn.metrics import mean_squared_error
mse_3 = mean_squared_error(ytest, y_pred_3)
print('Mean Squared Error:', mse_3)
#ROOT MEAN SQUARED ERROR
import numpy as np
from sklearn.metrics import mean_squared_error
mse_3= mean_squared_error(ytest, y_pred_3)
rmse_3 = np.sqrt(mse_3)
print('Root Mean Squared Error:', rmse_3)
#MEAN ABSOLUTE ERROR
from sklearn.metrics import mean_absolute_error
mae_3 = mean_absolute_error(ytest, y_pred_3)
print('Mean Absolute Error:', mae_3)
# Out:
# Mean Squared Error: 464.7611570708197
# Root Mean Squared Error: 21.558319903712807
# Mean Absolute Error: 15.322727272727274

# %%
#xg boost regressor
import xgboost as xgb
xgbr = xgb.XGBRegressor()
xgbr.fit(xtrain, ytrain)
y_pred_4= xgbr.predict(xtest)

# %%
#MEAN SQUARD ERROR
from sklearn.metrics import mean_squared_error
mse_4 = mean_squared_error(ytest, y_pred_4)
print('Mean Squared Error:', mse_4)
#ROOT MEAN SQUARED ERROR
import numpy as np
from sklearn.metrics import mean_squared_error
mse_4= mean_squared_error(ytest, y_pred_4)
rmse_4 = np.sqrt(mse_4)
print('Root Mean Squared Error:', rmse_4)
#MEAN ABSOLUTE ERROR
from sklearn.metrics import mean_absolute_error
mae_4= mean_absolute_error(ytest, y_pred_4)
print('Mean Absolute Error:', mae_4)
# Out:
# Mean Squared Error: 347.86579364212764
# Root Mean Squared Error: 18.651160651340913
# Mean Absolute Error: 11.920219305444768

# %%
#Some Basic Visualizations on Real World or Augmented Data
plt.figure(figsize=(15,6))
sns.scatterplot(x=df['AQI'],y=df['PM10 in æg/m3'])
plt.show()
